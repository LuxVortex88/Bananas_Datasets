# %%
# Bananas consumption dataset in pandas
import pandas as pd

# Define the data
data = {
    "Person": ["Jack", "Bob", "Charlie", "Diana"],
    "Meal": ["Breakfast", "Lunch", "Snack", "Dinner"],
    "Bananas Portions": [8, 4, 5, 3],
    "Portion Type": ["Slices", "Cup", "Slices", None]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Display the full dataset
print("🍌 Bananas Consumption Dataset")
display(df)

# Create a summary table
summary = df[["Person", "Bananas Portions"]].copy()
summary.columns = ["Person", "Bananas Portions"]

print("\n📊 Summary Table")
display(summary)
# Out:
# 🍌 Bananas Consumption Dataset
#     Person       Meal  Bananas Portions Portion Type
# 0     Jack  Breakfast                 8       Slices
# 1      Bob      Lunch                 4          Cup
# 2  Charlie      Snack                 5       Slices
# 3    Diana     Dinner                 3         None
# 📊 Summary Table
#     Person  Bananas Portions
# 0     Jack                 8
# 1      Bob                 4
# 2  Charlie                 5
# 3    Diana                 3
